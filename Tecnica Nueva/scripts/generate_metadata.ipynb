# %%
PATH='/content/drive/MyDrive/Tesis/Real-ESRGAN'
import os
os.chdir(PATH)

# %%
# !python scripts/generate_meta_info_pairdata.py --input datasets/breast_phantoms/train/gt datasets/breast_phantoms/train/lq --meta_info datasets/breast_phantoms/meta_info/toybreast_pair.txt
# Out:
# gt/data_1_01.mat, lq/data_1_01.mat
# gt/data_1_010.mat, lq/data_1_010.mat
# gt/data_1_02.mat, lq/data_1_02.mat
# gt/data_1_03.mat, lq/data_1_03.mat
# gt/data_1_04.mat, lq/data_1_04.mat
# gt/data_1_05.mat, lq/data_1_05.mat
# gt/data_1_06.mat, lq/data_1_06.mat
# gt/data_1_07.mat, lq/data_1_07.mat
# gt/data_1_08.mat, lq/data_1_08.mat
# gt/data_1_09.mat, lq/data_1_09.mat
# gt/data_2_01.mat, lq/data_2_01.mat
# gt/data_2_010.mat, lq/data_2_010.mat
# gt/data_2_02.mat, lq/data_2_02.mat
# gt/data_2_03.mat, lq/data_2_03.mat
# gt/data_2_04.mat, lq/data_2_04.mat
# gt/data_2_05.mat, lq/data_2_05.mat
# gt/data_2_06.mat, lq/data_2_06.mat
# gt/data_2_07.mat, lq/data_2_07.mat
# gt/data_2_08.mat, lq/data_2_08.mat
# gt/data_2_09.mat, lq/data_2_09.mat
